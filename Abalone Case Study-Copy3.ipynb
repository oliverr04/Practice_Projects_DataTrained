# %% [markdown]
# Practice Project-4

# %% [markdown]
# # Abalone Case Study

# %% [markdown]
# The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task. Other measurements, which are easier to obtain, are used to predict the age.

# %% [markdown]
# # Attribute Information

# %% [markdown]
# Given is the attribute name, attribute type, the measurement unit and a brief description. The number of rings is the value to predict.
#
# Name / Data Type / Measurement Unit / Description
# -----------------------------
# Sex / nominal / -- / M, F, and I (infant)
# Length / continuous / mm / Longest shell measurement
# Diameter / continuous / mm / perpendicular to length
# Height / continuous / mm / with meat in shell
# Whole weight / continuous / grams / whole abalone
# Shucked weight / continuous / grams / weight of meat
# Viscera weight / continuous / grams / gut weight (after bleeding)
# Shell weight / continuous / grams / after being dried
# Rings / integer / -- / +1.5 gives the age in years.

# %%
# Import Necessary Libraries
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Dataset
df_aba=pd.read_csv("Abalone.csv")
df_aba
# Out:
#      Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0         M   0.455     0.365   0.095        0.5140          0.2245
# 1         M   0.350     0.265   0.090        0.2255          0.0995
# 2         F   0.530     0.420   0.135        0.6770          0.2565
# 3         M   0.440     0.365   0.125        0.5160          0.2155
# 4         I   0.330     0.255   0.080        0.2050          0.0895
# ...     ...     ...       ...     ...           ...             ...
# 4172      F   0.565     0.450   0.165        0.8870          0.3700
# 4173      M   0.590     0.440   0.135        0.9660          0.4390
# 4174      M   0.600     0.475   0.205        1.1760          0.5255
# 4175      F   0.625     0.485   0.150        1.0945          0.5310
# 4176      M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# ...

# %%
# First 10 rows
df_aba.head(10)
# Out:
#   Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# 5      I   0.425     0.300   0.095        0.3515          0.1410
# 6      F   0.530     0.415   0.150        0.7775          0.2370
# 7      F   0.545     0.425   0.125        0.7680          0.2940
# 8      M   0.475     0.370   0.125        0.5095          0.2165
# 9      F   0.550     0.440   0.150        0.8945          0.3145
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7
# ...

# %%
# Last 10 rows
df_aba.tail(10)
# Out:
#      Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4167      M   0.500     0.380   0.125        0.5770          0.2690
# 4168      F   0.515     0.400   0.125        0.6150          0.2865
# 4169      M   0.520     0.385   0.165        0.7910          0.3750
# 4170      M   0.550     0.430   0.130        0.8395          0.3155
# 4171      M   0.560     0.430   0.155        0.8675          0.4000
# 4172      F   0.565     0.450   0.165        0.8870          0.3700
# 4173      M   0.590     0.440   0.135        0.9660          0.4390
# 4174      M   0.600     0.475   0.205        1.1760          0.5255
# 4175      F   0.625     0.485   0.150        1.0945          0.5310
# 4176      M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4167          0.1265        0.1535      9
# 4168          0.1230        0.1765      8
# 4169          0.1800        0.1815     10
# 4170          0.1955        0.2405     10
# ...

# %%
# Sample
df_aba.sample(4)
# Out:
#      Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 910       I   0.340      0.25   0.075        0.1785          0.0665
# 1126      M   0.560      0.43   0.145        0.8995          0.4640
# 3386      M   0.515      0.40   0.125        0.9550          0.3410
# 2777      I   0.585      0.42   0.145        0.6735          0.2895
#
#       Viscera weight  Shell weight  Rings
# 910           0.0455         0.045      5
# 1126          0.1775         0.234      9
# 3386          0.2535         0.260     13
# 2777          0.1345         0.220      9

# %%
df_aba.shape
# Out:
# (4177, 9)

# %% [markdown]
# This dataset contains 4177 rows and 9 columns.

# %% [markdown]
# # EDA

# %%
# Column Names
df_aba.columns
# Out:
# Index(['Gender', 'Length', 'Diameter', 'Height', 'Whole weight',
#        'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
# Checking for null values
df_aba.isnull()
# Out:
#       Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      False   False     False   False         False           False
# 1      False   False     False   False         False           False
# 2      False   False     False   False         False           False
# 3      False   False     False   False         False           False
# 4      False   False     False   False         False           False
# ...      ...     ...       ...     ...           ...             ...
# 4172   False   False     False   False         False           False
# 4173   False   False     False   False         False           False
# 4174   False   False     False   False         False           False
# 4175   False   False     False   False         False           False
# 4176   False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# ...

# %%
# Sum of null values if any...
df_aba.isnull().sum()
# Out:
# Gender            0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# There are no null values or missing values in the dataset.

# %%
# Checking the datatypes in each column
df_aba.dtypes
# Out:
# Gender             object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# The Gender column is of object data type. Rings column is of integer data type. All other columns are of float data type.

# %%
df_aba.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
# Means of our target variable 'Rings'
df_aba.groupby('Rings').mean()
# Out:
#          Length  Diameter    Height  Whole weight  Shucked weight  \
# Rings
# 1      0.075000  0.055000  0.010000      0.002000        0.001000
# 2      0.150000  0.100000  0.025000      0.015000        0.004500
# 3      0.176000  0.128667  0.041667      0.028400        0.011767
# 4      0.221491  0.161579  0.053947      0.059605        0.024719
# 5      0.285739  0.210696  0.069913      0.125500        0.061696
# 6      0.369363  0.278861  0.091776      0.273174        0.123158
# 7      0.422033  0.321535  0.105921      0.397386        0.182657
# 8      0.498776  0.384798  0.128556      0.640753        0.293773
# 9      0.546865  0.425218  0.142721      0.852013        0.387938
# 10     0.574629  0.449290  0.154093      1.008748        0.447217
# 11     0.599374  0.470595  0.161253      1.142559        0.503977
# 12     0.589457  0.462434  0.161292      1.102904        0.472781
# 13     0.578892  0.456453  0.160887      1.075453        0.434638
# ...

# %%
df_aba.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
# Visualizing df_aba.corr() using heatmap
plt.figure(figsize=(20,7))
sns.heatmap(df_aba.corr(),annot=True,cmap='Blues',linewidths=0.1,linecolor="black",fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
df_aba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# # Data Visualization

# %%
df_aba.nunique()
# Out:
# Gender               3
# Length             134
# Diameter           111
# Height              51
# Whole weight      2429
# Shucked weight    1515
# Viscera weight     880
# Shell weight       926
# Rings               28
# dtype: int64

# %%
sns.countplot(df_aba['Gender'])
plt.show()

# %%
sns.countplot(df_aba['Rings'])
plt.show()

# %%
sns.distplot(df_aba['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(df_aba['Diameter'])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sns.distplot(df_aba['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
plt.scatter(df_aba['Rings'], df_aba['Whole weight'], color = 'green')
plt.title('relation of Whole weight with Rings of the Abalone')
plt.xlabel('Rings')
plt.ylabel('Whole weight')
plt.show()

# %%
plt.scatter(df_aba['Rings'], df_aba['Shucked weight'], color = 'red')
plt.title('relation of Shucked weight with Rings of the Abalone')
plt.xlabel('Rings')
plt.ylabel('Shucked weight')
plt.show()

# %%
plt.scatter(df_aba['Rings'], df_aba['Viscera weight'], color = 'yellow')
plt.title('relation of Viscera weight with Rings of the Abalone')
plt.xlabel('Rings')
plt.ylabel('Viscera weight')
plt.show()

# %%
plt.scatter(df_aba['Rings'], df_aba['Shell weight'], color = 'pink')
plt.title('relation of Shell weight with Rings of the Abalone')
plt.xlabel('Rings')
plt.ylabel('Shell weight')
plt.show()

# %%
plt.bar(df_aba['Rings'], df_aba['Length'], color = 'brown')
plt.title('relation between Length & the Rings on the abalone')
plt.xlabel('Rings')
plt.ylabel('Length')
plt.show()

# %%
plt.bar(df_aba['Rings'], df_aba['Diameter'], color = 'purple')
plt.title('relation between Diameter & the Rings on the abalone')
plt.xlabel('Rings')
plt.ylabel('Diameter')
plt.show()

# %%
plt.bar(df_aba['Rings'], df_aba['Height'], color = 'blue')
plt.title('relation between Height & the Rings on the abalone')
plt.xlabel('Rings')
plt.ylabel('Height')
plt.show()

# %%
df_aba.hist(figsize=(15,15),bins=50)
plt.show()

# %% [markdown]
# # Encoding the Data Frame

# %%
df_aba.dtypes
# Out:
# Gender             object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# Ordinal encoder is used to convert the data frame so that all the columns have the same data type. Encoding is necessary for model creation, model training and model testing.

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

# %%
for i in df_aba.columns:
    if df_aba[i].dtypes=="object":
        df_aba[i]=oe.fit_transform(df_aba[i].values.reshape(-1,1))

# %%
df_aba
# Out:
#       Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0        2.0   0.455     0.365   0.095        0.5140          0.2245
# 1        2.0   0.350     0.265   0.090        0.2255          0.0995
# 2        0.0   0.530     0.420   0.135        0.6770          0.2565
# 3        2.0   0.440     0.365   0.125        0.5160          0.2155
# 4        1.0   0.330     0.255   0.080        0.2050          0.0895
# ...      ...     ...       ...     ...           ...             ...
# 4172     0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173     2.0   0.590     0.440   0.135        0.9660          0.4390
# 4174     2.0   0.600     0.475   0.205        1.1760          0.5255
# 4175     0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176     2.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# ...

# %% [markdown]
# # Skewness

# %%
df_aba.skew()
# Out:
# Gender           -0.098155
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %% [markdown]
# Removing Skewness with Power Transform

# %%
from sklearn.preprocessing import power_transform
df_aba_new=power_transform(df_aba)

# %%
df_aba
# Out:
#       Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0        2.0   0.455     0.365   0.095        0.5140          0.2245
# 1        2.0   0.350     0.265   0.090        0.2255          0.0995
# 2        0.0   0.530     0.420   0.135        0.6770          0.2565
# 3        2.0   0.440     0.365   0.125        0.5160          0.2155
# 4        1.0   0.330     0.255   0.080        0.2050          0.0895
# ...      ...     ...       ...     ...           ...             ...
# 4172     0.0   0.565     0.450   0.165        0.8870          0.3700
# 4173     2.0   0.590     0.440   0.135        0.9660          0.4390
# 4174     2.0   0.600     0.475   0.205        1.1760          0.5255
# 4175     0.0   0.625     0.485   0.150        1.0945          0.5310
# 4176     2.0   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# ...

# %%
type(df_aba_new)
# Out:
# numpy.ndarray

# %%
df_aba.columns
# Out:
# Index(['Gender', 'Length', 'Diameter', 'Height', 'Whole weight',
#        'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
df_aba1=pd.DataFrame(df_aba_new,columns=df_aba.columns)

# %%
df_aba1.skew()
# Out:
# Gender           -0.176442
# Length           -0.066669
# Diameter         -0.065977
# Height           -0.115483
# Whole weight     -0.003980
# Shucked weight    0.027351
# Viscera weight    0.039780
# Shell weight      0.023390
# Rings             0.004429
# dtype: float64

# %%
df_aba1[np.abs(df_aba1)>0.25].all()
# Out:
# Gender            True
# Length            True
# Diameter          True
# Height            True
# Whole weight      True
# Shucked weight    True
# Viscera weight    True
# Shell weight      True
# Rings             True
# dtype: bool

# %% [markdown]
# # Outliers

# %%
df_aba1.plot(kind='box',subplots=True,layout=(2,9))
# Out:
# Gender               AxesSubplot(0.125,0.536818;0.0731132x0.343182)
# Length            AxesSubplot(0.212736,0.536818;0.0731132x0.343182)
# Diameter          AxesSubplot(0.300472,0.536818;0.0731132x0.343182)
# Height            AxesSubplot(0.388208,0.536818;0.0731132x0.343182)
# Whole weight      AxesSubplot(0.475943,0.536818;0.0731132x0.343182)
# Shucked weight    AxesSubplot(0.563679,0.536818;0.0731132x0.343182)
# Viscera weight    AxesSubplot(0.651415,0.536818;0.0731132x0.343182)
# Shell weight      AxesSubplot(0.739151,0.536818;0.0731132x0.343182)
# Rings             AxesSubplot(0.826887,0.536818;0.0731132x0.343182)
# dtype: object

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# Z-Score is used to remove outliers.

# %%
from scipy.stats import zscore
z=np.abs(zscore(df_aba1))
threshold=3
print(np.where(z>3))
# Out:
# (array([ 163,  166,  236,  236,  237,  237,  238,  238,  294,  306,  306,
#         480,  520,  526,  694,  719,  719,  720,  720,  891,  894, 1054,
#        1174, 1209, 1257, 1417, 1428, 1428, 1429, 1763, 1987, 2051, 2108,
#        2108, 2115, 2161, 2169, 2171, 2172, 2201, 2209, 2334, 2371, 2381,
#        2711, 2711, 3149, 3190, 3280, 3472, 3521, 3801, 3902, 3996],
#       dtype=int64), array([7, 7, 3, 8, 3, 8, 3, 8, 8, 3, 8, 8, 8, 8, 3, 3, 8, 3, 8, 7, 8, 8,
#        3, 5, 3, 3, 1, 2, 8, 6, 3, 3, 7, 8, 8, 7, 3, 3, 3, 8, 8, 1, 8, 3,
#        3, 8, 8, 3, 8, 8, 8, 8, 3, 3], dtype=int64))

# %%
# New data frame
df_new_aba=df_aba1[(z<3).all(axis=1)]
df_new_aba
# Out:
#         Gender    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0     1.127072 -0.685502 -0.549860 -1.124512     -0.576766       -0.540989
# 1     1.127072 -1.396344 -1.387333 -1.264396     -1.351761       -1.311662
# 2    -1.307935 -0.070774  0.008537 -0.064823     -0.198099       -0.366116
# 3     1.127072 -0.797286 -0.549860 -0.320227     -0.571893       -0.591672
# 4    -0.009459 -1.513796 -1.459659 -1.549424     -1.413146       -1.380201
# ...        ...       ...       ...       ...           ...             ...
# 4172 -1.307935  0.249836  0.345636  0.666117      0.241948        0.194158
# 4173  1.127072  0.492813  0.230611 -0.064823      0.395706        0.495450
# 4174  1.127072  0.593366  0.645191  1.565082      0.777944        0.838137
# 4175 -1.307935  0.853375  0.769928  0.307083      0.633874        0.858739
# 4176  1.127072  1.834478  1.726289  1.347943      1.937323        2.103648
#
#       Viscera weight  Shell weight     Rings
# ...

# %%
df_new_aba.shape
# Out:
# (4132, 9)

# %%
df_aba.shape
# Out:
# (4177, 9)

# %%
Data_loss=((4177-4132)/4177)*100
Data_loss
# Out:
# 1.0773282259995212

# %% [markdown]
# The data loss is 1.07 %

# %%
sns.pairplot(df_new_aba)

# %% [markdown]
# # Model Building

# %%
# dividing the dataset into independent and dependent variables
x=df_new_aba.drop("Rings", axis=1)
y=df_new_aba["Rings"]

# %%
x.shape
# Out:
# (4132, 8)

# %%
y.shape
# Out:
# (4132,)

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=scale.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=43)

# %%
x_train.shape
# Out:
# (3099, 8)

# %%
x_test.shape
# Out:
# (1033, 8)

# %%
y_train.shape
# Out:
# (3099,)

# %%
y_test.shape
# Out:
# (1033,)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([ 0.00478172, -0.15178532,  0.16393623,  0.37529426,  1.29785314,
#        -1.31123359, -0.23903176,  0.46827607])

# %%
lr.intercept_
# Out:
# 0.002746961127120244

# %%
lr.score(x_train,y_train)
# Out:
# 0.5729278398594874

# %%
# Predicting the value
pred_lr=lr.predict(x_test)
print("Predicted value: ",pred_lr)
print("Actual value: ",y_test)
# Out:
# Predicted value:  [-0.19040941 -0.52143442  0.64278133 ... -0.51984991 -0.21763541
#   0.60071093]
# Actual value:  3022   -0.542223
# 1276   -0.542223
# 2313    1.699293
# 4021    0.156908
# 3574   -0.176075
#           ...
# 2266    1.252182
# 1808    0.156908
# 3871    0.744607
# 3258   -0.949135
# 2969    0.156908
# Name: Rings, Length: 1033, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean absolute error: ',mean_absolute_error(y_test,pred_lr))
print('Mean squared error: ',mean_squared_error(y_test,pred_lr))

print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# Error:
# Mean absolute error:  0.4858800027909279
# Mean squared error:  0.3903294826159423
# Root Mean squared error:  0.624763541362604

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred_lr))
# Out:
# 0.5715701627549364

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(lr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.49753931888643466

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls= Lasso()

# %%
ls = Lasso(alpha=0.0001,random_state=0)
ls.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.0001, random_state=0)

# %%
ls.score(x_train,y_train)
# Out:
# 0.5729237676069265

# %%
ls.coef_
# Out:
# array([ 0.00466957, -0.14660101,  0.15892704,  0.37519334,  1.27910447,
#        -1.30290552, -0.2336507 ,  0.47362646])

# %%
pred_ls=ls.predict(x_test)
print("Predicted value: ",pred_ls)
print("Actual value: ",y_test)
# Out:
# Predicted value:  [-0.19105481 -0.5203134   0.64048486 ... -0.52095546 -0.21783418
#   0.60504847]
# Actual value:  3022   -0.542223
# 1276   -0.542223
# 2313    1.699293
# 4021    0.156908
# 3574   -0.176075
#           ...
# 2266    1.252182
# 1808    0.156908
# 3871    0.744607
# 3258   -0.949135
# 2969    0.156908
# Name: Rings, Length: 1033, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean absolute error: ',mean_absolute_error(y_test,pred_ls))
print('Mean squared error: ',mean_squared_error(y_test,pred_ls))

print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Error:
# Mean absolute error:  0.48585598500960814
# Mean squared error:  0.39022133508558904
# Root Mean squared error:  0.6246769845973109

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred_ls))
# Out:
# 0.5716888666471385

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.49753053276563985

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
rd= Ridge()

# %%
rd = Ridge(alpha=0.0001,random_state=0)
rd.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.0001, random_state=0)

# %%
rd.score(x_train,y_train)
# Out:
# 0.5729278398589744

# %%
rd.coef_
# Out:
# array([ 0.00478171, -0.1517852 ,  0.16393605,  0.37529429,  1.29784516,
#        -1.31122969, -0.23902999,  0.46827857])

# %%
pred_rd=rd.predict(x_test)
print("Predicted value: ",pred_rd)
print("Actual value: ",y_test)
# Out:
# Predicted value:  [-0.19040941 -0.52143434  0.64278081 ... -0.51985008 -0.21763489
#   0.60071154]
# Actual value:  3022   -0.542223
# 1276   -0.542223
# 2313    1.699293
# 4021    0.156908
# 3574   -0.176075
#           ...
# 2266    1.252182
# 1808    0.156908
# 3871    0.744607
# 3258   -0.949135
# 2969    0.156908
# Name: Rings, Length: 1033, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean absolute error: ',mean_absolute_error(y_test,pred_rd))
print('Mean squared error: ',mean_squared_error(y_test,pred_rd))

print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# Error:
# Mean absolute error:  0.4858799979027752
# Mean squared error:  0.3903294387144155
# Root Mean squared error:  0.6247635062280891

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred_rd))
# Out:
# 0.5715702109417243

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(rd,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.49753933931160643

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor(random_state=0)
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
dtr.score(x_train,y_train)
# Out:
# 1.0

# %%
pred_dtr=dtr.predict(x_test)
print("Predicted value: ",pred_dtr)
print("Actual value: ",y_test)
# Out:
# Predicted value:  [-0.54222341 -0.54222341  1.25218195 ... -0.94913462 -0.94913462
#   0.15690844]
# Actual value:  3022   -0.542223
# 1276   -0.542223
# 2313    1.699293
# 4021    0.156908
# 3574   -0.176075
#           ...
# 2266    1.252182
# 1808    0.156908
# 3871    0.744607
# 3258   -0.949135
# 2969    0.156908
# Name: Rings, Length: 1033, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean absolute error: ',mean_absolute_error(y_test,pred_dtr))
print('Mean squared error: ',mean_squared_error(y_test,pred_dtr))

print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# Error:
# Mean absolute error:  0.631231301531811
# Mean squared error:  0.7105032705694091
# Root Mean squared error:  0.8429135605561279

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred_dtr))
# Out:
# 0.22014397033993205

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(dtr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.10116527807527272

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse','mae'], 'max_features':["auto", "sqrt"]}
rfr =RandomForestRegressor()
gd= GridSearchCV(rfr,parameters)
gd.fit(x_train,y_train)

print(gd.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf= RandomForestRegressor(criterion="mae",max_features="sqrt")
rf.fit(x_train, y_train)
rf.score(x_train, y_train)
# Out:
# 0.9350863845982791

# %%
pred_rfr = rf.predict(x_test)
print("Predicted value: ",pred_rfr)
print("Actual value: ",y_test)
# Out:
# Predicted value:  [-0.2388029  -0.60242067  0.55693599 ... -0.15644801 -0.01265137
#   0.40551615]
# Actual value:  3022   -0.542223
# 1276   -0.542223
# 2313    1.699293
# 4021    0.156908
# 3574   -0.176075
#           ...
# 2266    1.252182
# 1808    0.156908
# 3871    0.744607
# 3258   -0.949135
# 2969    0.156908
# Name: Rings, Length: 1033, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean absolute error: ',mean_absolute_error(y_test,pred_rfr))
print('Mean squared error: ',mean_squared_error(y_test,pred_rfr))

print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_rfr)))
# Out:
# Error:
# Mean absolute error:  0.4599052360050611
# Mean squared error:  0.35497227970864387
# Root Mean squared error:  0.5957955015847668

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred_rfr))
# Out:
# 0.6103786088540983

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(rfr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.5333746746838773

# %% [markdown]
# From the above models, Lasso ,Ridge and Linear Regression show similar r2 scores and cross validation scores.

# %% [markdown]
# The highest cross validation and r2 score belong to the Random Forest Regressor model. Also, the lowest cross validation score and r2 score belong to Decision tree Regressor model.

# %%
import numpy as np
act=np.array(y_test)
pred=np.array(rf.predict(x_test))
age_of_abalone=pd.DataFrame({'Actual':act,'Predicted':pred})
age_of_abalone
# Out:
#         Actual  Predicted
# 0    -0.542223  -0.238803
# 1    -0.542223  -0.602421
# 2     1.699293   0.556936
# 3     0.156908   0.792006
# 4    -0.176075   0.265006
# ...        ...        ...
# 1028  1.252182   0.355582
# 1029  0.156908   0.177327
# 1030  0.744607  -0.156448
# 1031 -0.949135  -0.012651
# 1032  0.156908   0.405516
#
# [1033 rows x 2 columns]

# %% [markdown]
# # Saving the Best Model

# %% [markdown]
# Since Random Forest Regression is showing the highest Cross Validation Score we save the Random Forest Regression Model

# %%
import pickle
filename='abalone_age_model.pkl'
pickle.dump(rf,open(filename,'wb'))
