# %% [markdown]
# Practice project - 1

# %% [markdown]
# # World Happiness Report

# %% [markdown]
# # Introduction

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th.
#
# The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.

# %% [markdown]
# # Dystopia

# %% [markdown]
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.

# %%
# Import Necessary Libraries
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Dataset
df_whr=pd.read_csv("happiness_score_dataset.csv")
df_whr
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.
# The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.

# %%
# First 10 rows
df_whr.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
# Last 10 rows
df_whr.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %%
# Sample
df_whr.sample(4)
# Out:
#                Country                           Region  Happiness Rank  \
# 97  Dominican Republic      Latin America and Caribbean              98
# 48             Bahrain  Middle East and Northern Africa              49
# 30      Czech Republic       Central and Eastern Europe              31
# 42           Guatemala      Latin America and Caribbean              43
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 97            4.885         0.07446                   0.89537  1.17202
# 48            5.960         0.05412                   1.32376  1.21624
# 30            6.505         0.04168                   1.17898  1.20643
# 42            6.123         0.05224                   0.74553  1.04356
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 97                   0.66825  0.57672                        0.14234
# 48                   0.74716  0.45492                        0.30600
# ...

# %%
df_whr.shape
# Out:
# (158, 12)

# %% [markdown]
# This dataset contains 158 rows and 12 columns.

# %% [markdown]
# # EDA

# %%
# Column Names
df_whr.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# Checking for null values
df_whr.isnull()
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      False   False           False            False           False
# 1      False   False           False            False           False
# 2      False   False           False            False           False
# 3      False   False           False            False           False
# 4      False   False           False            False           False
# ..       ...     ...             ...              ...             ...
# 153    False   False           False            False           False
# 154    False   False           False            False           False
# 155    False   False           False            False           False
# 156    False   False           False            False           False
# 157    False   False           False            False           False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
# Sum of null values if any...
df_whr.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# There are no null or missing values in the dataset.

# %%
# Checking the datatypes in each column
df_whr.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# Most of the columns are of float data type.
# Happiness Rank is of integer data type.
# Country & Region are object data type

# %%
df_whr.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
# Visualizing df_whr.describe() using heatmap
plt.figure(figsize=(20,7))
sns.heatmap(df_whr.describe(),annot=True,linewidths=0.1,linecolor="white",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
df_whr.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
# Visualizing df_whr.corr() using heatmap
plt.figure(figsize=(20,7))
sns.heatmap(df_whr.corr(),annot=True,linewidths=0.1,linecolor="black",fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
df_whr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# # Encoding the Data Frame

# %% [markdown]
# Ordinal encoder is used to convert the data frame so that all the columns have the same data type. Encoding is necessary for model creation, model training and model testing.

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

# %%
for i in df_whr.columns:
    if df_whr[i].dtypes=="object":
        df_whr[i]=oe.fit_transform(df_whr[i].values.reshape(-1,1))

# %%
df_whr
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# # Skewness

# %%
df_whr.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# Following columns don't lie within the Skewness range of -0.5 to +0.5.
#
# Standard Error, Family, Health (Life Expectancy), Trust (Government Corruption), Generosity

# %% [markdown]
# # Outliers

# %%
df_whr['Country'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df_whr['Region'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df_whr['Happiness Score'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df_whr['Standard Error'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df_whr['Economy (GDP per Capita)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df_whr['Family'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df_whr['Health (Life Expectancy)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df_whr['Freedom'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df_whr['Trust (Government Corruption)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df_whr['Generosity'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in : Generosity, Trust(Government Corruption), Family & Standard Error

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# Using Z-SCORE to remove outliers from the dataset

# %%
from scipy.stats import zscore

z=np.abs(zscore(df_whr))
threshold=3
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
df_whr.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %%
# Visualizing df_whr.describe() after encoding
plt.figure(figsize=(20,7))
sns.heatmap(df_whr.describe(),annot=True,linewidths=0.1,linecolor="white",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
df_whr.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
# Visualizing df_whr.corr() after encoding
plt.figure(figsize=(20,7))
sns.heatmap(df_whr.corr(),annot=True,linewidths=0.1,linecolor="black",fmt=".2f")
# Out:
# <AxesSubplot:>

# %%
# New data frame
df_new_whr=df_whr[(z<3).all(axis=1)]
df_new_whr
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150     66.0     8.0             151            3.655         0.05141
# 151     20.0     8.0             152            3.587         0.04324
# 152      0.0     7.0             153            3.575         0.03084
# 154     13.0     8.0             155            3.340         0.03656
# 156     21.0     8.0             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# A New dataset is created after removing outliers values.

# %%
df_new_whr.shape
# Out:
# (149, 12)

# %%
df_whr.shape
# Out:
# (158, 12)

# %%
Data_loss=((158-149)/158)*100
Data_loss
# Out:
# 5.69620253164557

# %% [markdown]
# Data Loss Percentage is 5.69%.

# %%
sns.pairplot(df_new_whr)

# %% [markdown]
# # Model Building

# %% [markdown]
# Since we have to predict the happiness score considering all the other factors in the dataset, we have to drop the column " Happiness Score".

# %% [markdown]
# We will put all the remaining column data in the variable x. And a new column which is the target column ("Happiness Score") in the variable y.

# %%
x=df_new_whr.drop("Happiness Score", axis=1)
y=df_new_whr["Happiness Score"]

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr_whr=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=41)

# %%
lr_whr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train.shape
# Out:
# (104, 11)

# %%
x_test.shape
# Out:
# (45, 11)

# %%
y_train.shape
# Out:
# (104,)

# %%
y_test.shape
# Out:
# (45,)

# %%
lr_whr.coef_
# Out:
# array([-8.55122031e-07, -1.02718040e-05, -1.03740010e-06,  2.05344393e-03,
#         1.00006992e+00,  9.99924154e-01,  9.99815443e-01,  9.99728208e-01,
#         9.99925382e-01,  1.00003892e+00,  9.99971433e-01])

# %%
lr_whr.intercept_
# Out:
# 0.0004142689418040746

# %%
lr_whr.score(x_train,y_train)
# Out:
# 0.9999999456226852

# %%
# Predicting the value
pred_test=lr_whr.predict(x_test)
print("Predicted value: ",pred_test)
print("Actual value: ",y_test)
# Out:
# Predicted value:  [6.29481102 6.26935874 6.48508744 6.7977041  5.54814842 4.4192867
#  3.95566299 5.85526088 4.63347568 5.6047185  4.2520335  4.97115309
#  3.89650146 4.50719501 4.36925628 5.1242395  4.43552716 5.82831521
#  6.13022903 3.99480256 3.34008236 6.00273324 7.52699299 5.6952736
#  5.39870572 4.68561909 4.78800657 5.82411186 5.9870997  4.60959678
#  5.36017845 3.58690917 3.65509721 7.11943542 5.09762839 5.88900884
#  5.05723939 5.12885255 4.8742604  4.21858844 6.45460856 5.81261311
#  3.93073677 6.93734811 4.55052351]
# Actual value:  38     6.295
# 39     6.269
# 31     6.485
# 23     6.798
# 69     5.548
# 124    4.419
# 139    3.956
# 53     5.855
# 113    4.633
# 67     5.605
# 132    4.252
# 93     4.971
# 142    3.896
# 122    4.507
# 125    4.369
# 85     5.124
# 123    4.436
# 56     5.828
# 41     6.130
# 137    3.995
# 154    3.340
# 43     6.003
# 2      7.527
# 65     5.695
# 73     5.399
# 109    4.686
# 104    4.788
# 57     5.824
# 45     5.987
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean absolute error: ',mean_absolute_error(y_test,pred_test))
print('Mean squared error: ',mean_squared_error(y_test,pred_test))

print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# Error:
# Mean absolute error:  0.0002571576672860725
# Mean squared error:  8.688748265842444e-08
# Root Mean squared error:  0.0002947668276085768

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred_test))
# Out:
# 0.9999999144781491

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(lr_whr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.9999981468771427

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls_whr= Lasso()

# %%
ls_whr = Lasso(alpha=0.0001,random_state=0)
ls_whr.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.0001, random_state=0)

# %%
ls_whr.score(x_train,y_train)
# Out:
# 0.9999766776103093

# %%
ls_whr.coef_
# Out:
# array([ 1.61160376e-06,  3.77397997e-04, -1.09041901e-03, -0.00000000e+00,
#         9.56601247e-01,  9.54089167e-01,  9.54276832e-01,  9.58929971e-01,
#         9.64869797e-01,  9.53530525e-01,  9.56870791e-01])

# %%
pred_ls=ls_whr.predict(x_test)
print("Predicted value: ",pred_ls)
print("Actual value: ",y_test)
# Out:
# Predicted value:  [6.29994081 6.2742725  6.48908053 6.79944892 5.5514274  4.4121322
#  3.95415698 5.86098905 4.63023702 5.60754898 4.24471535 4.97591779
#  3.89340337 4.50040384 4.36677516 5.1259739  4.43033478 5.83307486
#  6.13821664 3.9933362  3.34964102 6.01463713 7.52072432 5.69732298
#  5.40233577 4.68177839 4.7846349  5.82742469 5.99574593 4.60592428
#  5.36719622 3.58792971 3.65543353 7.11364123 5.09687346 5.89477598
#  5.0622747  5.13661875 4.87095833 4.20625689 6.45595281 5.81466501
#  3.92775701 6.93733463 4.54605973]
# Actual value:  38     6.295
# 39     6.269
# 31     6.485
# 23     6.798
# 69     5.548
# 124    4.419
# 139    3.956
# 53     5.855
# 113    4.633
# 67     5.605
# 132    4.252
# 93     4.971
# 142    3.896
# 122    4.507
# 125    4.369
# 85     5.124
# 123    4.436
# 56     5.828
# 41     6.130
# 137    3.995
# 154    3.340
# 43     6.003
# 2      7.527
# 65     5.695
# 73     5.399
# 109    4.686
# 104    4.788
# 57     5.824
# 45     5.987
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean absolute error: ',mean_absolute_error(y_test,pred_ls))
print('Mean squared error: ',mean_squared_error(y_test,pred_ls))

print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# Error:
# Mean absolute error:  0.0044683732541805415
# Mean squared error:  2.766773511630867e-05
# Root Mean squared error:  0.005260012843739896

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred_ls))
# Out:
# 0.9999727671254229

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(ls_whr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.9975515894770114

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
rd_whr= Ridge()

# %%
rd_whr = Ridge(alpha=0.0001,random_state=0)
rd_whr.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.0001, random_state=0)

# %%
rd_whr.score(x_train,y_train)
# Out:
# 0.9999999433588699

# %%
rd_whr.coef_
# Out:
# array([-8.55176922e-07, -7.07337152e-06, -1.19737778e-05,  1.04187837e-03,
#         9.99639357e-01,  9.99470510e-01,  9.99330768e-01,  9.99311155e-01,
#         9.99561461e-01,  9.99583738e-01,  9.99537618e-01])

# %%
pred_rd=rd_whr.predict(x_test)
print("Predicted value: ",pred_rd)
print("Actual value: ",y_test)
# Out:
# Predicted value:  [6.2948641  6.2693547  6.48512216 6.79771687 5.54818811 4.41921748
#  3.95564742 5.85532637 4.63344343 5.60474408 4.25196627 4.97117523
#  3.89647574 4.50711302 4.36919516 5.12423637 4.43548394 5.82835087
#  6.13029739 3.99478409 3.3401882  6.00285363 7.52693404 5.69527505
#  5.39876666 4.68558305 4.78796172 5.82414213 5.9871908  4.60956469
#  5.36025407 3.58692759 3.65510219 7.1193815  5.09762433 5.88907656
#  5.05727176 5.12890757 4.87424729 4.2184667  6.45463338 5.81264234
#  3.93071277 6.93735101 4.55046091]
# Actual value:  38     6.295
# 39     6.269
# 31     6.485
# 23     6.798
# 69     5.548
# 124    4.419
# 139    3.956
# 53     5.855
# 113    4.633
# 67     5.605
# 132    4.252
# 93     4.971
# 142    3.896
# 122    4.507
# 125    4.369
# 85     5.124
# 123    4.436
# 56     5.828
# 41     6.130
# 137    3.995
# 154    3.340
# 43     6.003
# 2      7.527
# 65     5.695
# 73     5.399
# 109    4.686
# 104    4.788
# 57     5.824
# 45     5.987
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean absolute error: ',mean_absolute_error(y_test,pred_rd))
print('Mean squared error: ',mean_squared_error(y_test,pred_rd))

print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# Error:
# Mean absolute error:  0.00025745905609717565
# Mean squared error:  8.292666604911187e-08
# Root Mean squared error:  0.0002879699047628274

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred_rd))
# Out:
# 0.9999999183767125

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(rd_whr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.999997881526127

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse','mae'], 'max_features':["auto", "sqrt","log2"]}
rfr =RandomForestRegressor()
gd= GridSearchCV(rfr,parameters)
gd.fit(x_train,y_train)

print(gd.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf= RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(x_train, y_train)
rf.score(x_train, y_train)
pred_decision = rf.predict(x_test)

# %%
rfs = r2_score(y_test,pred_decision)
print('R2 Score:', rfs*100)
# Out:
# R2 Score: 99.66594275346552

# %%
rfscore = cross_val_score(rf,x,y,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:', rfc*100)
# Out:
# Cross Val Score: -176.06407911444148

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean absolute error: ',mean_absolute_error(y_test,pred_decision))
print('Mean squared error: ',mean_squared_error(y_test,pred_decision))

print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_decision)))
# Out:
# Error:
# Mean absolute error:  0.035967111111110776
# Mean squared error:  0.003393915462222207
# Root Mean squared error:  0.0582573211040656

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dtr_whr = DecisionTreeRegressor(random_state = 0)

# %%
dtr_whr = DecisionTreeRegressor(random_state=0)
dtr_whr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
dtr_whr.score(x_train,y_train)
# Out:
# 1.0

# %%
pred_dtr=dtr_whr.predict(x_test)
print("Predicted value: ",pred_dtr)
print("Actual value: ",y_test)
# Out:
# Predicted value:  [6.411 6.411 6.505 6.786 5.429 4.297 3.989 5.948 4.565 5.754 4.332 5.013
#  3.904 4.642 4.292 5.123 4.642 5.77  6.123 3.989 3.575 6.123 7.587 5.689
#  5.332 4.565 4.8   5.77  5.995 4.642 5.332 3.667 3.667 7.286 5.102 5.878
#  5.14  5.14  4.867 4.35  6.574 5.759 3.904 6.94  4.642]
# Actual value:  38     6.295
# 39     6.269
# 31     6.485
# 23     6.798
# 69     5.548
# 124    4.419
# 139    3.956
# 53     5.855
# 113    4.633
# 67     5.605
# 132    4.252
# 93     4.971
# 142    3.896
# 122    4.507
# 125    4.369
# 85     5.124
# 123    4.436
# 56     5.828
# 41     6.130
# 137    3.995
# 154    3.340
# 43     6.003
# 2      7.527
# 65     5.695
# 73     5.399
# 109    4.686
# 104    4.788
# 57     5.824
# 45     5.987
# 114    4.610
# 74     5.360
# 151    3.587
# 150    3.655
# 14     7.119
# 88     5.098
# 51     5.889
# 90     5.057
# 84     5.129
# 99     4.874
# 133    4.218
# 33     6.455
# 58     5.813
# 140    3.931
# 18     6.937
# 117    4.550
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

print('Error:')

print('Mean absolute error: ',mean_absolute_error(y_test,pred_dtr))
print('Mean squared error: ',mean_squared_error(y_test,pred_dtr))

print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# Error:
# Mean absolute error:  0.06753333333333328
# Mean squared error:  0.008015444444444431
# Root Mean squared error:  0.08952901453966994

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred_dtr))
# Out:
# 0.9921105362503402

# %%
from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(dtr_whr,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -1.5898826362407639

# %% [markdown]
# From the above models the R2 Score of  Linear Regression and Ridge Regression are the highest. There is a very small amount of difference between the R2 Scores of the other models.

# %% [markdown]
# Decision Tree Regressor and Random Forest Regressor show a Negative Cross Validation Score.
#
#  Whereas, Lasso, Ridge and Linear Regression Models show a Positive Cross Validation Score.

# %% [markdown]
# # Model Saving

# %% [markdown]
# Since Ridge Regression is showing the highest R2 Score we save the Ridge Regression Model

# %%
import pickle
filename='whr_model.pkl'
pickle.dump(rd_whr,open(filename,'wb'))
